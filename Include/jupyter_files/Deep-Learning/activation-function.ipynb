# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pylab import rcParams
import matplotlib.pyplot as plt
import warnings
from mlxtend.plotting import plot_decision_regions
from matplotlib.colors import ListedColormap
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
import seaborn as sns

# %%
X,y=make_classification(n_samples=1000,n_features=2,n_informative=2,n_redundant=0,n_classes=2,n_clusters_per_class=1,random_state=110)
plt.scatter(X[:, 0], X[:, 1], marker='o', c=y,s=25, edgecolor='k')
plt.show()

# %%
model=Sequential()

model.add(Dense(100,input_dim=2,activation="linear"))
model.add(Dense(50,input_dim=2,activation="linear"))
model.add(Dense(1,activation="sigmoid"))

adom=Adam(learning_rate=0.01)
model.compile(loss='binary_crossentropy',optimizer=adom,metrics=['accuracy'])
model.fit(X,y,validation_split=0.2,epochs=200)
# Out:
# Epoch 1/200
# 25/25 [==============================] - 1s 9ms/step - loss: 0.1388 - accuracy: 0.9787 - val_loss: 0.1997 - val_accuracy: 0.9850
# Epoch 2/200
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0683 - accuracy: 0.9875 - val_loss: 0.1027 - val_accuracy: 0.9850
# Epoch 3/200
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0627 - accuracy: 0.9912 - val_loss: 0.1317 - val_accuracy: 0.9650
# Epoch 4/200
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0753 - accuracy: 0.9837 - val_loss: 0.1065 - val_accuracy: 0.9850
# Epoch 5/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0620 - accuracy: 0.9887 - val_loss: 0.1091 - val_accuracy: 0.9850
# Epoch 6/200
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0659 - accuracy: 0.9887 - val_loss: 0.1298 - val_accuracy: 0.9650
# Epoch 7/200
# ...

# %%
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(X,y.astype('int'),clf=model,legend=50)

plt.xlim(-0.7,0.5)
plt.ylim(-0.8,0.8)

plt.show()
# Out:
# 9600/9600 [==============================] - 17s 2ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 3
#       1 from mlxtend.plotting import plot_decision_regions
# ----> 3 plot_decision_regions(X,y.astype('int'),clf=model,legend=50)
#       5 plt.xlim(-0.7,0.5)
#       6 plt.ylim(-0.8,0.8)
#
# File d:\python programs\All\.venv\Lib\site-packages\mlxtend\plotting\decision_regions.py:401, in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#     399     else:
#     400         handles, labels = ax.get_legend_handles_labels()
# --> 401         ax.legend(handles, labels, framealpha=0.3, scatterpoints=1, loc=legend)
#     403 return ax
#
# ...

# %% [markdown]
# Using relu

# %%
model=Sequential()

model.add(Dense(100,input_dim=2,activation="relu"))
model.add(Dense(50,input_dim=2,activation="relu"))
model.add(Dense(1,activation="sigmoid"))

adom=Adam(learning_rate=0.01)
model.compile(loss='binary_crossentropy',optimizer=adom,metrics=['accuracy'])
model.fit(X,y,validation_split=0.2,epochs=200)
# Out:
# Epoch 1/200
# 25/25 [==============================] - 1s 10ms/step - loss: 0.1438 - accuracy: 0.9712 - val_loss: 0.1438 - val_accuracy: 0.9850
# Epoch 2/200
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0857 - accuracy: 0.9837 - val_loss: 0.1017 - val_accuracy: 0.9850
# Epoch 3/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0530 - accuracy: 0.9887 - val_loss: 0.0907 - val_accuracy: 0.9800
# Epoch 4/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0537 - accuracy: 0.9900 - val_loss: 0.1086 - val_accuracy: 0.9700
# Epoch 5/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0607 - accuracy: 0.9887 - val_loss: 0.0963 - val_accuracy: 0.9800
# Epoch 6/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0530 - accuracy: 0.9875 - val_loss: 0.0859 - val_accuracy: 0.9850
# Epoch 7/200
# ...

# %%
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(X,y.astype('int'),clf=model,legend=50)

plt.xlim(-0.7,0.5)
plt.ylim(-0.8,0.8)

plt.show()
# Out:
# 9600/9600 [==============================] - 16s 2ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 3
#       1 from mlxtend.plotting import plot_decision_regions
# ----> 3 plot_decision_regions(X,y.astype('int'),clf=model,legend=50)
#       5 plt.xlim(-0.7,0.5)
#       6 plt.ylim(-0.8,0.8)
#
# File d:\python programs\All\.venv\Lib\site-packages\mlxtend\plotting\decision_regions.py:401, in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#     399     else:
#     400         handles, labels = ax.get_legend_handles_labels()
# --> 401         ax.legend(handles, labels, framealpha=0.3, scatterpoints=1, loc=legend)
#     403 return ax
#
# ...
