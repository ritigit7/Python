# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

X,y=make_moons(n_samples=500,noise=0.18)

plt.scatter(X[:, 0], X[:, 1], marker='o', c=y,s=25, edgecolor='k')
print(X[:1,:],y[0])
plt.show()
X.shape
# Out:
# [[-0.35188691  1.10817952]] 0
# (500, 2)

# %%
import tensorflow 
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense
import numpy as np
from tensorflow.keras.layers import BatchNormalization 

model=Sequential()
model.add(Dense(4,activation='relu',input_dim=2))
model.add(Dense(2,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

model.summary()

#with batch noramlization
model2=Sequential()
model2.add(Dense(4,activation='relu',input_dim=2))
model2.add(BatchNormalization())
model2.add(Dense(2,activation='relu'))
model2.add(BatchNormalization())
model2.add(Dense(1,activation='sigmoid'))

model2.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_21 (Dense)            (None, 4)                 12
#
#  dense_22 (Dense)            (None, 2)                 10
#
#  dense_23 (Dense)            (None, 1)                 3
#
# ...
# Total params: 25 (100.00 Byte)
# Trainable params: 25 (100.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_24 (Dense)            (None, 4)                 12
#
#  batch_normalization_4 (Bat  (None, 4)                 16
#  chNormalization)
#
#  dense_25 (Dense)            (None, 2)                 10
#
#  batch_normalization_5 (Bat  (None, 2)                 8
#  chNormalization)
#
# ...

# %%
model.compile(optimizer='adam',metrics=['accuracy'],loss='binary_crossentropy')
history=model.fit(X,y,epochs=300,validation_split=0.2)
model2.compile(optimizer='adam',metrics=['accuracy'],loss='binary_crossentropy')
history2=model.fit(X,y,epochs=300,validation_split=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model.compile(optimizer='adam',metrics=['accuracy'],loss='binary_crossentropy')
#       2 history=model.fit(X,y,epochs=300,validation_split=0.2)
#       3 model2.compile(optimizer='adam',metrics=['accuracy'],loss='binary_crossentropy')
#
# NameError: name 'model' is not defined

# %%
plt.plot(history.history['accuracy'],c='r')

# %%
plt.plot(history2.history['accuracy'],c='b')

# %%
plt.plot(history.history['loss'],c='r')
plt.plot(history2.history['loss'],c='b')

# %%
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(X,y.astype('int'),clf=model,legend=50)

plt.xlim(-0.7,0.5)
plt.ylim(-0.8,0.8)

plt.show()
# Out:
# 9600/9600 [==============================] - 17s 2ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 3
#       1 from mlxtend.plotting import plot_decision_regions
# ----> 3 plot_decision_regions(X,y.astype('int'),clf=model,legend=50)
#       5 plt.xlim(-0.7,0.5)
#       6 plt.ylim(-0.8,0.8)
#
# File d:\python programs\All\.venv\Lib\site-packages\mlxtend\plotting\decision_regions.py:401, in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#     399     else:
#     400         handles, labels = ax.get_legend_handles_labels()
# --> 401         ax.legend(handles, labels, framealpha=0.3, scatterpoints=1, loc=legend)
#     403 return ax
#
# ...

# %%
p=[[0,1.5],
   [1,-1.2]
   ]

import math
ans=model.predict(p)
print(ans[0]*100,ans[1]*100)
# Out:
# 1/1 [==============================] - 0s 65ms/step
# [0.00790608] [99.999985]
