# %%
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt

X,y=make_classification(n_samples=500,n_features=2,n_informative=2,n_redundant=0,n_classes=2,n_clusters_per_class=1,random_state=500)

plt.scatter(X[:, 0], X[:, 1], marker='o', c=y,s=25, edgecolor='k')
plt.show()

# %%
import tensorflow 
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense
import numpy as np

model=Sequential()
model.add(Dense(2,activation='relu',input_dim=2))
model.add(Dense(1,activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_8 (Dense)             (None, 2)                 6
#
#  dense_9 (Dense)             (None, 1)                 3
#
# ...
# Total params: 9 (36.00 Byte)
# Trainable params: 9 (36.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
initial_weights=model.get_weights()
# initial_weights[0]=np.zeros(model.get_weights()[0].shape)
# initial_weights[1]=np.zeros(model.get_weights()[1].shape) 
# initial_weights[2]=np.zeros(model.get_weights()[2].shape)
# initial_weights[3]=np.zeros(model.get_weights()[3].shape)
initial_weights[0]=np.ones(model.get_weights()[0].shape)
initial_weights[1]=np.ones(model.get_weights()[1].shape) 
initial_weights[2]=np.ones(model.get_weights()[2].shape)
initial_weights[3]=np.ones(model.get_weights()[3].shape)

model.set_weights(initial_weights)
model.get_weights()
# Out:
# [array([[1., 1.],
#         [1., 1.]], dtype=float32),
#  array([1., 1.], dtype=float32),
#  array([[1.],
#         [1.]], dtype=float32),
#  array([1.], dtype=float32)]

# %%
model.compile(optimizer='adam',metrics=['accuracy'],loss='binary_crossentropy')
history=model.fit(X,y,epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 1s 20ms/step - loss: 0.9031 - accuracy: 0.4975 - val_loss: 0.8710 - val_accuracy: 0.5100
# Epoch 2/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.8904 - accuracy: 0.4975 - val_loss: 0.8590 - val_accuracy: 0.5100
# Epoch 3/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.8780 - accuracy: 0.4975 - val_loss: 0.8476 - val_accuracy: 0.5100
# Epoch 4/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.8664 - accuracy: 0.4975 - val_loss: 0.8364 - val_accuracy: 0.5100
# Epoch 5/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.8548 - accuracy: 0.4975 - val_loss: 0.8260 - val_accuracy: 0.5100
# Epoch 6/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.8441 - accuracy: 0.4975 - val_loss: 0.8157 - val_accuracy: 0.5100
# Epoch 7/100
# ...

# %%
model.get_weights()
#[array([[1.3707849, 1.3707849], same weight
#         [1.7283151, 1.7283151]], dtype=float32),,same weight
#  array([0.05632066, 0.05632066], dtype=float32),
#  array([[1.2376169],
#         [1.2376169]], dtype=float32),
#  array([-0.7724125], dtype=float32)]
#act like single perceptron
# Out:
# [array([[1.6976048, 1.6976048],
#         [1.8478364, 1.8478364]], dtype=float32),
#  array([0.29724467, 0.29724467], dtype=float32),
#  array([[1.328363],
#         [1.328363]], dtype=float32),
#  array([-0.09745657], dtype=float32)]
